# %% [markdown]
# Демонстрация локального запуска:
#
# ![image.png](photos/local_run.png)
#
# Конфигурация в gns3:
#
# ![image.png](photos/configuration.png)
#
# Пример запуска с клиентами за разными NAT в gns3:
#
# ![image.png](photos/server.png)
#
# ![image.png](photos/PC1.png)
#
# ![image.png](photos/PC2.png)
